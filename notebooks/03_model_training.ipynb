# %% [markdown]
# # Model Training - Infant Cry Classification
#
# This notebook implements and trains the deep learning models for infant cry classification.

# %%
import sys
sys.path.append('..')

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import pandas as pd
from pathlib import Path

from src.data_preprocessing.dataset import AudioDataset
from src.models.efficientnet_lstm import EfficientNetLSTM
from src.training.train import train_model
from src.training.utils import setup_logging, save_checkpoint

# %% [markdown]
# ## Setup Training

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Set paths
DATA_DIR = Path('../data')
SPEC_DIR = DATA_DIR / 'spectrograms'
LABELS_FILE = DATA_DIR / 'labels.csv'
CHECKPOINT_DIR = Path('../experiments/checkpoints')
CHECKPOINT_DIR.mkdir(exist_ok=True)
