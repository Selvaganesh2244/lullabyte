# %% [markdown]
# # Data Exploration - Infant Cry Classification
#
# This notebook explores the raw audio data and generates visualizations to understand the characteristics of infant cries.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
from pathlib import Path

from src.data_preprocessing.audio_loader import load_audio
from src.visualization.audio_viz import plot_waveform, plot_spectrogram

# %% [markdown]
# ## Load Data

# %%
# Set paths
DATA_DIR = Path('../data')
RAW_DIR = DATA_DIR / 'raw'
LABELS_FILE = DATA_DIR / 'labels.csv'

# Load metadata
labels_df = pd.read_csv(LABELS_FILE)
print(f"Total samples: {len(labels_df)}")
print("\nLabel distribution:")
print(labels_df['label'].value_counts())
