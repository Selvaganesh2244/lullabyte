# %% [markdown]
# # Model Evaluation - Infant Cry Classification
#
# This notebook evaluates the trained models and visualizes their performance metrics.

# %%
import sys
sys.path.append('..')

import torch
import pandas as pd
from pathlib import Path

from src.training.evaluate import evaluate_model
from src.models.efficientnet_lstm import EfficientNetLSTM
from src.visualization.plot_metrics import plot_confusion_matrix
from src.data_preprocessing.dataset import AudioDataset

# %% [markdown]
# ## Load Model and Data

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Set paths
DATA_DIR = Path('../data')
SPEC_DIR = DATA_DIR / 'spectrograms'
LABELS_FILE = DATA_DIR / 'labels.csv'
CHECKPOINT_DIR = Path('../experiments/checkpoints')
RESULTS_DIR = Path('../experiments/results')
RESULTS_DIR.mkdir(exist_ok=True)
