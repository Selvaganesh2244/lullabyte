# %% [markdown]
# # Feature Extraction - Infant Cry Classification
#
# This notebook demonstrates the feature extraction process, converting raw audio into spectrograms and MFCCs.

# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm

from src.data_preprocessing.audio_loader import load_audio
from src.data_preprocessing.feature_extractor import extract_melspectrogram, extract_mfcc

# %% [markdown]
# ## Extract Features

# %%
# Set paths
DATA_DIR = Path('../data')
RAW_DIR = DATA_DIR / 'raw'
SPEC_DIR = DATA_DIR / 'spectrograms'
LABELS_FILE = DATA_DIR / 'labels.csv'

# Create output directory
SPEC_DIR.mkdir(exist_ok=True)

# Load metadata
labels_df = pd.read_csv(LABELS_FILE)
